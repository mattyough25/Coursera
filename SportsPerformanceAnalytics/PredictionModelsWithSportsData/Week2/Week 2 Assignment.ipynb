# %%
# install the packages we need

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data

NBA19 = pd.read_excel("D:\\GitHub\\Coursera\\SportsPerformanceAnalytics\\PredictionModelsWithSportsData\\data\\NBA2019odds.xlsx")
NBA19
# Out:
#                     team             opponent  day  month  year  winodds  \
# 0          Atlanta Hawks      New York Knicks   18     10  2018     2.39
# 1          Atlanta Hawks    Memphis Grizzlies   20     10  2018     3.34
# 2          Atlanta Hawks  Cleveland Cavaliers   22     10  2018     3.97
# 3          Atlanta Hawks     Dallas Mavericks   25     10  2018     2.07
# 4          Atlanta Hawks        Chicago Bulls   28     10  2018     1.43
# ...                  ...                  ...  ...    ...   ...      ...
# 2455  Washington Wizards       Denver Nuggets    1      4  2019     5.68
# 2456  Washington Wizards        Chicago Bulls    4      4  2019     1.19
# 2457  Washington Wizards    San Antonio Spurs    6      4  2019     3.22
# 2458  Washington Wizards      New York Knicks    8      4  2019     1.58
# 2459  Washington Wizards       Boston Celtics   10      4  2019     1.51
#
#       loseodds  teampts  oppopts  overtime  home  \
# ...

# %%
# Calculate the implied win probability from the decimal odds

NBA19['winprob']= 1/(NBA19['winodds'])/(1/(NBA19['winodds'])+ 1/(NBA19['loseodds']))
NBA19
# Out:
#                     team             opponent  day  month  year  winodds  \
# 0          Atlanta Hawks      New York Knicks   18     10  2018     2.39
# 1          Atlanta Hawks    Memphis Grizzlies   20     10  2018     3.34
# 2          Atlanta Hawks  Cleveland Cavaliers   22     10  2018     3.97
# 3          Atlanta Hawks     Dallas Mavericks   25     10  2018     2.07
# 4          Atlanta Hawks        Chicago Bulls   28     10  2018     1.43
# ...                  ...                  ...  ...    ...   ...      ...
# 2455  Washington Wizards       Denver Nuggets    1      4  2019     5.68
# 2456  Washington Wizards        Chicago Bulls    4      4  2019     1.19
# 2457  Washington Wizards    San Antonio Spurs    6      4  2019     3.22
# 2458  Washington Wizards      New York Knicks    8      4  2019     1.58
# 2459  Washington Wizards       Boston Celtics   10      4  2019     1.51
#
#       loseodds  teampts  oppopts  overtime  home  \
# ...

# %%
NBA19 = NBA19[NBA19['home'] != 0]
NBA19
# Out:
#                     team           opponent  day  month  year  winodds  \
# 3          Atlanta Hawks   Dallas Mavericks   25     10  2018     2.07
# 4          Atlanta Hawks      Chicago Bulls   28     10  2018     1.43
# 7          Atlanta Hawks   Sacramento Kings    2     11  2018     2.16
# 8          Atlanta Hawks         Miami Heat    4     11  2018     2.91
# 10         Atlanta Hawks    New York Knicks    8     11  2018     2.00
# ...                  ...                ...  ...    ...   ...      ...
# 2450  Washington Wizards     Denver Nuggets   22      3  2019     4.06
# 2451  Washington Wizards         Miami Heat   24      3  2019     1.83
# 2456  Washington Wizards      Chicago Bulls    4      4  2019     1.19
# 2457  Washington Wizards  San Antonio Spurs    6      4  2019     3.22
# 2459  Washington Wizards     Boston Celtics   10      4  2019     1.51
#
#       loseodds  teampts  oppopts  overtime  home  \
# 3         1.79      111      104         0     1
# ...

# %%
NBA19.corr()
# Out:
#                day     month      year   winodds  loseodds   teampts  \
# day       1.000000  0.110607 -0.160322 -0.021328  0.020338  0.018466
# month     0.110607  1.000000 -0.979375 -0.051976 -0.037247 -0.072427
# year     -0.160322 -0.979375  1.000000  0.059743  0.036677  0.068906
# winodds  -0.021328 -0.051976  0.059743  1.000000 -0.519700 -0.211101
# loseodds  0.020338 -0.037247  0.036677 -0.519700  1.000000  0.237857
# teampts   0.018466 -0.072427  0.068906 -0.211101  0.237857  1.000000
# oppopts   0.008639 -0.079511  0.083059  0.235809 -0.203061  0.344336
# overtime  0.016095  0.037273 -0.032301  0.022753 -0.078881  0.257128
# home           NaN       NaN       NaN       NaN       NaN       NaN
# win       0.028164  0.026641 -0.029216 -0.344866  0.308797  0.462650
# winprob   0.019050  0.004125 -0.009708 -0.842090  0.808441  0.252475
#
#            oppopts  overtime  home       win   winprob
# day       0.008639  0.016095   NaN  0.028164  0.019050
# ...

# %%
# point differential is less than 9
NBA_Less9 = NBA19[abs(NBA19['teampts'] - NBA19['oppopts']) < 9]

# %%
NBA_Less9.corr()
# Out:
#                day     month      year   winodds  loseodds   teampts  \
# day       1.000000  0.106887 -0.152579 -0.040675  0.069440  0.028233
# month     0.106887  1.000000 -0.980472 -0.012117 -0.057065 -0.095356
# year     -0.152579 -0.980472  1.000000  0.005980  0.065811  0.109497
# winodds  -0.040675 -0.012117  0.005980  1.000000 -0.578952 -0.052170
# loseodds  0.069440 -0.057065  0.065811 -0.578952  1.000000  0.016257
# teampts   0.028233 -0.095356  0.109497 -0.052170  0.016257  1.000000
# oppopts  -0.018689 -0.117887  0.129969  0.059545 -0.059723  0.896585
# overtime -0.006233  0.063516 -0.057381  0.058482 -0.100176  0.428033
# home           NaN       NaN       NaN       NaN       NaN       NaN
# win       0.101453  0.055742 -0.050467 -0.193338  0.141073  0.205815
# winprob   0.059623 -0.028230  0.036246 -0.879254  0.828825  0.031989
#
#            oppopts  overtime  home       win   winprob
# day      -0.018689 -0.006233   NaN  0.101453  0.059623
# ...

# %%
# point differential is greater than 9
NBA_More9 = NBA19[abs(NBA19['teampts'] - NBA19['oppopts']) > 9]

# %%
NBA_More9.corr()
# Out:
#                day     month      year   winodds  loseodds   teampts  \
# day       1.000000  0.120184 -0.174718  0.015962 -0.020077  0.019217
# month     0.120184  1.000000 -0.978261 -0.090102 -0.016970 -0.043613
# year     -0.174718 -0.978261  1.000000  0.107757  0.010098  0.026976
# winodds   0.015962 -0.090102  0.107757  1.000000 -0.501747 -0.303680
# loseodds -0.020077 -0.016970  0.010098 -0.501747  1.000000  0.379109
# teampts   0.019217 -0.043613  0.026976 -0.303680  0.379109  1.000000
# oppopts   0.009702 -0.055673  0.053651  0.367279 -0.276493 -0.029990
# overtime  0.013059 -0.046209  0.035817 -0.026428  0.026923  0.045192
# home           NaN       NaN       NaN       NaN       NaN       NaN
# win      -0.014125  0.019970 -0.031787 -0.475397  0.442884  0.670262
# winprob  -0.025104  0.045479 -0.063591 -0.833790  0.798721  0.410297
#
#            oppopts  overtime  home       win   winprob
# day       0.009702  0.013059   NaN -0.014125 -0.025104
# ...

# %%
# Overtime games
NBA_OT = NBA19[NBA19['overtime'] == 1]

# %%
NBA_OT.corr()
# Out:
#                day     month      year   winodds  loseodds   teampts  \
# day       1.000000  0.027213 -0.038114 -0.216240  0.275625  0.100390
# month     0.027213  1.000000 -0.981528  0.044510  0.017936 -0.309640
# year     -0.038114 -0.981528  1.000000 -0.034598 -0.014337  0.319084
# winodds  -0.216240  0.044510 -0.034598  1.000000 -0.712465 -0.124235
# loseodds  0.275625  0.017936 -0.014337 -0.712465  1.000000  0.024143
# teampts   0.100390 -0.309640  0.319084 -0.124235  0.024143  1.000000
# oppopts  -0.004591 -0.294500  0.298137 -0.067374  0.016434  0.929410
# overtime       NaN       NaN       NaN       NaN       NaN       NaN
# home           NaN       NaN       NaN       NaN       NaN       NaN
# win       0.290799  0.001468  0.016086 -0.059349 -0.012001  0.116252
# winprob   0.271896  0.005750 -0.008926 -0.917810  0.908381  0.071647
#
#            oppopts  overtime  home       win   winprob
# day      -0.004591       NaN   NaN  0.290799  0.271896
# ...

# %%
# Regulation games
NBA_Reg = NBA19[NBA19['overtime'] == 0]

# %%
NBA_Reg.corr()
# Out:
#                day     month      year   winodds  loseodds   teampts  \
# day       1.000000  0.115044 -0.167201 -0.011925  0.015037  0.009739
# month     0.115044  1.000000 -0.979236 -0.057686 -0.036104 -0.071906
# year     -0.167201 -0.979236  1.000000  0.065251  0.035827  0.066035
# winodds  -0.011925 -0.057686  0.065251  1.000000 -0.517657 -0.229609
# loseodds  0.015037 -0.036104  0.035827 -0.517657  1.000000  0.276582
# teampts   0.009739 -0.071906  0.066035 -0.229609  0.276582  1.000000
# oppopts   0.004436 -0.083167  0.085133  0.257146 -0.196401  0.248599
# overtime       NaN       NaN       NaN       NaN       NaN       NaN
# home           NaN       NaN       NaN       NaN       NaN       NaN
# win       0.012789  0.029220 -0.032843 -0.358883  0.318945  0.507802
# winprob   0.007058  0.006264 -0.011688 -0.839181  0.809366  0.287038
#
#            oppopts  overtime  home       win   winprob
# day       0.004436       NaN   NaN  0.012789  0.007058
# ...

# %%
# 2018 Games
NBA_2018 = NBA19[NBA19['year'] == 2018]

# %%
NBA_2018.corr()
# Out:
#                day     month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000 -0.291933   NaN -0.117968  0.093707  0.076537  0.045858
# month    -0.291933  1.000000   NaN  0.025453 -0.049268 -0.073787 -0.061571
# year           NaN       NaN   NaN       NaN       NaN       NaN       NaN
# winodds  -0.117968  0.025453   NaN  1.000000 -0.586110 -0.203359  0.221029
# loseodds  0.093707 -0.049268   NaN -0.586110  1.000000  0.232770 -0.181776
# teampts   0.076537 -0.073787   NaN -0.203359  0.232770  1.000000  0.341215
# oppopts   0.045858 -0.061571   NaN  0.221029 -0.181776  0.341215  1.000000
# overtime -0.019835  0.034872   NaN  0.060960 -0.082372  0.220374  0.273822
# home           NaN       NaN   NaN       NaN       NaN       NaN       NaN
# win       0.033941 -0.008495   NaN -0.326073  0.275301  0.472634 -0.426843
# winprob   0.122102 -0.048380   NaN -0.871581  0.851068  0.249337 -0.218721
#
#           overtime  home       win   winprob
# ...

# %%
# 2019 Games
NBA_2019 = NBA19[NBA19['year'] == 2019]

# %%
NBA_2019.corr()
# Out:
#                day     month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000 -0.203886   NaN  0.047147 -0.015550 -0.005691  0.003626
# month    -0.203886  1.000000   NaN  0.035237  0.013079  0.002594  0.050367
# year           NaN       NaN   NaN       NaN       NaN       NaN       NaN
# winodds   0.047147  0.035237   NaN  1.000000 -0.495213 -0.227166  0.243815
# loseodds -0.015550  0.013079   NaN -0.495213  1.000000  0.239871 -0.225756
# teampts  -0.005691  0.002594   NaN -0.227166  0.239871  1.000000  0.340204
# oppopts   0.003626  0.050367   NaN  0.243815 -0.225756  0.340204  1.000000
# overtime  0.038256  0.024611   NaN  0.002352 -0.076260  0.296396  0.345298
# home           NaN       NaN   NaN       NaN       NaN       NaN       NaN
# win       0.016036 -0.010655   NaN -0.360023  0.334621  0.460832 -0.460829
# winprob  -0.055044 -0.015797   NaN -0.835435  0.786799  0.257323 -0.306142
#
#           overtime  home       win   winprob
# ...

# %%
NBA_Oct = NBA19[NBA19['month'] == 10]

# %%
NBA_Oct.corr()
# Out:
#                day  month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000    NaN   NaN  0.106227 -0.097936 -0.067056  0.029854
# month          NaN    NaN   NaN       NaN       NaN       NaN       NaN
# year           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# winodds   0.106227    NaN   NaN  1.000000 -0.535633 -0.141126  0.351952
# loseodds -0.097936    NaN   NaN -0.535633  1.000000  0.194536 -0.176553
# teampts  -0.067056    NaN   NaN -0.141126  0.194536  1.000000  0.407989
# oppopts   0.029854    NaN   NaN  0.351952 -0.176553  0.407989  1.000000
# overtime  0.034884    NaN   NaN -0.037524 -0.073669  0.213610  0.260017
# home           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# win      -0.019114    NaN   NaN -0.399096  0.314758  0.465549 -0.414928
# winprob  -0.079347    NaN   NaN -0.829803  0.855516  0.210061 -0.294564
#
#           overtime  home       win   winprob
# day       0.034884   NaN -0.019114 -0.079347
# ...

# %%
NBA_Nov = NBA19[NBA19['month'] == 11]

# %%
NBA_Nov.corr()
# Out:
#                day  month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000    NaN   NaN -0.117200  0.149684  0.082676  0.015386
# month          NaN    NaN   NaN       NaN       NaN       NaN       NaN
# year           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# winodds  -0.117200    NaN   NaN  1.000000 -0.626534 -0.284652  0.069406
# loseodds  0.149684    NaN   NaN -0.626534  1.000000  0.278449 -0.102237
# teampts   0.082676    NaN   NaN -0.284652  0.278449  1.000000  0.308902
# oppopts   0.015386    NaN   NaN  0.069406 -0.102237  0.308902  1.000000
# overtime -0.053404    NaN   NaN  0.077419 -0.113321  0.193587  0.223232
# home           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# win       0.030823    NaN   NaN -0.314411  0.254686  0.539252 -0.368895
# winprob   0.131422    NaN   NaN -0.909629  0.845098  0.314361 -0.085978
#
#           overtime  home       win   winprob
# day      -0.053404   NaN  0.030823  0.131422
# ...

# %%
NBA_Dec = NBA19[NBA19['month'] == 12]

# %%
NBA_Dec.corr()
# Out:
#                day  month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000    NaN   NaN -0.176543  0.064395  0.047533  0.023260
# month          NaN    NaN   NaN       NaN       NaN       NaN       NaN
# year           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# winodds  -0.176543    NaN   NaN  1.000000 -0.580738 -0.164967  0.287799
# loseodds  0.064395    NaN   NaN -0.580738  1.000000  0.200363 -0.274462
# teampts   0.047533    NaN   NaN -0.164967  0.200363  1.000000  0.327860
# oppopts   0.023260    NaN   NaN  0.287799 -0.274462  0.327860  1.000000
# overtime  0.040108    NaN   NaN  0.084037 -0.049127  0.264467  0.339047
# home           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# win       0.035291    NaN   NaN -0.300936  0.277762  0.415771 -0.491966
# winprob   0.132683    NaN   NaN -0.866724  0.855656  0.198248 -0.321607
#
#           overtime  home       win   winprob
# day       0.040108   NaN  0.035291  0.132683
# ...

# %%
NBA_Jan = NBA19[NBA19['month'] == 1]

# %%
NBA_Jan.corr()
# Out:
#                day  month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000    NaN   NaN  0.057403  0.027950 -0.089232  0.000693
# month          NaN    NaN   NaN       NaN       NaN       NaN       NaN
# year           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# winodds   0.057403    NaN   NaN  1.000000 -0.533928 -0.233614  0.353196
# loseodds  0.027950    NaN   NaN -0.533928  1.000000  0.316782 -0.212136
# teampts  -0.089232    NaN   NaN -0.233614  0.316782  1.000000  0.279297
# oppopts   0.000693    NaN   NaN  0.353196 -0.212136  0.279297  1.000000
# overtime -0.052547    NaN   NaN -0.020781 -0.056259  0.247676  0.337407
# home           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# win      -0.051173    NaN   NaN -0.453119  0.372539  0.467900 -0.500348
# winprob  -0.034849    NaN   NaN -0.886425  0.780651  0.305623 -0.344126
#
#           overtime  home       win   winprob
# day      -0.052547   NaN -0.051173 -0.034849
# ...

# %%
NBA_Feb = NBA19[NBA19['month'] == 2]

# %%
NBA_Feb.corr()
# Out:
#                day  month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000    NaN   NaN  0.011214 -0.103977  0.112403  0.082788
# month          NaN    NaN   NaN       NaN       NaN       NaN       NaN
# year           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# winodds   0.011214    NaN   NaN  1.000000 -0.461893 -0.165634  0.136912
# loseodds -0.103977    NaN   NaN -0.461893  1.000000  0.232597 -0.162660
# teampts   0.112403    NaN   NaN -0.165634  0.232597  1.000000  0.452752
# oppopts   0.082788    NaN   NaN  0.136912 -0.162660  0.452752  1.000000
# overtime  0.099962    NaN   NaN  0.059086 -0.115287  0.298399  0.372708
# home           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# win       0.058596    NaN   NaN -0.310284  0.326475  0.466784 -0.376673
# winprob  -0.095096    NaN   NaN -0.781522  0.812194  0.202714 -0.192476
#
#           overtime  home       win   winprob
# day       0.099962   NaN  0.058596 -0.095096
# ...

# %%
NBA_Mar = NBA19[NBA19['month'] == 3]

# %%
NBA_Mar.corr()
# Out:
#                day  month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000    NaN   NaN  0.101949  0.053840  0.004897  0.002137
# month          NaN    NaN   NaN       NaN       NaN       NaN       NaN
# year           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# winodds   0.101949    NaN   NaN  1.000000 -0.543421 -0.222059  0.264971
# loseodds  0.053840    NaN   NaN -0.543421  1.000000  0.136761 -0.226403
# teampts   0.004897    NaN   NaN -0.222059  0.136761  1.000000  0.357561
# oppopts   0.002137    NaN   NaN  0.264971 -0.226403  0.357561  1.000000
# overtime  0.069926    NaN   NaN  0.008107 -0.081619  0.364103  0.383735
# home           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# win       0.017883    NaN   NaN -0.340895  0.292774  0.446774 -0.458364
# winprob  -0.040894    NaN   NaN -0.863310  0.815421  0.215464 -0.306884
#
#           overtime  home       win   winprob
# day       0.069926   NaN  0.017883 -0.040894
# ...

# %%
NBA_Apr = NBA19[NBA19['month'] == 4]

# %%
NBA_Apr.corr()
# Out:
#                day  month  year   winodds  loseodds   teampts   oppopts  \
# day       1.000000    NaN   NaN  0.124140 -0.039317  0.043360  0.110439
# month          NaN    NaN   NaN       NaN       NaN       NaN       NaN
# year           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# winodds   0.124140    NaN   NaN  1.000000 -0.480059 -0.377069  0.196836
# loseodds -0.039317    NaN   NaN -0.480059  1.000000  0.283390 -0.351137
# teampts   0.043360    NaN   NaN -0.377069  0.283390  1.000000  0.245022
# oppopts   0.110439    NaN   NaN  0.196836 -0.351137  0.245022  1.000000
# overtime  0.121864    NaN   NaN -0.059738 -0.078786  0.271505  0.240642
# home           NaN    NaN   NaN       NaN       NaN       NaN       NaN
# win      -0.002422    NaN   NaN -0.352581  0.382984  0.480868 -0.518904
# winprob  -0.135538    NaN   NaN -0.847809  0.754808  0.337300 -0.400337
#
#           overtime  home       win   winprob
# day       0.121864   NaN -0.002422 -0.135538
# ...
