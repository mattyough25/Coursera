# %% [markdown]
# ## Wearable Tech: Week 2 Assignment

# %% [markdown]
# ### Step 1

# %%
# imports
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime

#turns off warning for chained assignment as we are overwriting references to original dataframe
pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_rows', 30)

df = pd.read_csv("D:\\GitHub\\Coursera\\SportsPerformanceAnalytics\\WearableTechnologiesAndSportsAnalytics\\data\\Soccer.csv", parse_dates=["Date"])

# %% [markdown]
# ### Step 2

# %%
session_df = df.loc[df['Period.Name'] == "Session"]

session_df
# Out:
#       Player.Name Period.Name Position.Name  Total.Player.Load  \
# 0              12     Session             D          276.85373
# 1              89     Session            GK          238.00543
# 2              63     Session             F          231.84551
# 3              15     Session             D          355.02606
# 4              44     Session             D          318.82076
# ...           ...         ...           ...                ...
# 9499           23     Session            GK          185.24280
# 9500           21     Session             D         1364.75000
# 9501           43     Session             M         1294.72809
# 9502           91     Session             F          633.34450
# 9503           52     Session             D          665.25116
#
#       Player.Load.Per.Minute  Maximum.Heart.Rate  Minimum.Heart.Rate  \
# 0                   15.33448                 205                   0
# 1                   14.04880                 205                 101
# 2                   14.36184                 206                   0
# 3                   18.78379                 216                   0
# 4                   17.41175                 218                   0
# ...                      ...                 ...                 ...
# 9499                 4.66020                   0                   0
# 9500                 9.87637                 129                   0
# 9501                11.25361                 225                   0
# 9502                 6.94490                 128                   0
# 9503                 9.42482                   0                   0
#
#       Avg.Heart.Rate       Date
# 0          170.91685 2019-08-06
# 1          174.15563 2019-08-06
# 2          179.25900 2019-08-06
# 3          177.66543 2019-08-06
# 4          180.77740 2019-08-06
# ...              ...        ...
# 9499         0.00000 2019-11-24
# 9500       129.00000 2019-11-24
# 9501       166.42591 2019-11-24
# 9502       128.00000 2019-11-24
# 9503         0.00000 2019-11-24
#
# [2131 rows x 9 columns]

# %% [markdown]
# ### Step 3

# %%
session_df['Session.Duration'] = session_df['Total.Player.Load']/session_df['Player.Load.Per.Minute']
session_df
# Out:
#       Player.Name Period.Name Position.Name  Total.Player.Load  \
# 0              12     Session             D          276.85373
# 1              89     Session            GK          238.00543
# 2              63     Session             F          231.84551
# 3              15     Session             D          355.02606
# 4              44     Session             D          318.82076
# ...           ...         ...           ...                ...
# 9499           23     Session            GK          185.24280
# 9500           21     Session             D         1364.75000
# 9501           43     Session             M         1294.72809
# 9502           91     Session             F          633.34450
# 9503           52     Session             D          665.25116
#
#       Player.Load.Per.Minute  Maximum.Heart.Rate  Minimum.Heart.Rate  \
# 0                   15.33448                 205                   0
# 1                   14.04880                 205                 101
# 2                   14.36184                 206                   0
# 3                   18.78379                 216                   0
# 4                   17.41175                 218                   0
# ...                      ...                 ...                 ...
# 9499                 4.66020                   0                   0
# 9500                 9.87637                 129                   0
# 9501                11.25361                 225                   0
# 9502                 6.94490                 128                   0
# 9503                 9.42482                   0                   0
#
#       Avg.Heart.Rate       Date  Session.Duration
# 0          170.91685 2019-08-06         18.054328
# 1          174.15563 2019-08-06         16.941335
# 2          179.25900 2019-08-06         16.143162
# 3          177.66543 2019-08-06         18.900662
# 4          180.77740 2019-08-06         18.310667
# ...              ...        ...               ...
# 9499         0.00000 2019-11-24         39.749968
# 9500       129.00000 2019-11-24        138.183361
# 9501       166.42591 2019-11-24        115.050023
# 9502       128.00000 2019-11-24         91.195626
# 9503         0.00000 2019-11-24         70.585025
#
# [2131 rows x 10 columns]

# %% [markdown]
# ### Step 4

# %%
Rank_Total_PL = session_df.groupby(['Player.Name', 'Position.Name'])[['Total.Player.Load']].sum()
print("Total Player Load captured during entire season")


print(Rank_Total_PL.sort_values(by='Total.Player.Load', ascending = False))
# Out:
# Total Player Load captured during entire season
#                            Total.Player.Load
# Player.Name Position.Name
# 43          M                    61807.06587
# 62          F                    55455.84319
# 4           M                    54531.06541
# 21          D                    52448.84502
# 44          D                    45528.61318
# 66          M                    44035.16557
# 100         D                    43435.17877
# 39          D                    42966.83272
# 12          D                    42594.47149
# 52          D                    41966.27363
# 35          F                    39743.46043
# 86          M                    38332.92067
# 10          D                    35760.14918
# 63          F                    34497.65386
# 15          D                    32792.41598
# 18          D                    28582.29879
# 97          F                    28388.64588
# 49          F                    28331.33281
# 91          F                    27545.34959
# 48          M                    26757.18323
# 34          M                    26380.69503
# 89          GK                   25943.30417
# 9           F                    24544.28285
# 95          D                    21977.07917
# 23          GK                   16549.32121
# 71          GK                   14327.75353
# 95          F                     7041.19046
# 62          D                     1436.97360
# 98          GK                     269.72924

# %% [markdown]
# ### Step 5

# %%
session_df = session_df.sort_values(by = 'Total.Player.Load', ascending=False)
session_df.head(10)
# Out:
#       Player.Name Period.Name Position.Name  Total.Player.Load  \
# 8482           43     Session             M         1755.08710
# 9338           43     Session             M         1701.65860
# 4874           62     Session             F         1695.69403
# 4883           43     Session             M         1672.69440
# 4489           43     Session             M         1649.17551
# 5697            4     Session             M         1641.06146
# 3536           43     Session             M         1635.75719
# 5703           43     Session             M         1617.42587
# 8471           62     Session             F         1576.30459
# 5937            4     Session             M         1565.28558
#
#       Player.Load.Per.Minute  Maximum.Heart.Rate  Minimum.Heart.Rate  \
# 8482                11.85336                 218                   0
# 9338                12.84722                 229                   0
# 4874                12.77450                 210                   0
# 4883                13.69880                 217                   0
# 4489                11.38274                 219                   0
# 5697                10.75199                 205                  94
# 3536                 9.69604                 210                   0
# 5703                11.99220                 225                   0
# 8471                10.64591                 215                   0
# 5937                 9.92887                 199                   0
#
#       Avg.Heart.Rate       Date  Session.Duration
# 8482       162.17158 2019-11-08        148.066633
# 9338       168.91000 2019-11-22        132.453449
# 4874       147.47929 2019-09-19        132.740540
# 4883       165.77741 2019-09-19        122.105177
# 4489       164.28843 2019-09-13        144.883878
# 5697       170.58953 2019-09-29        152.628626
# 3536       150.83079 2019-09-01        168.703635
# 5703       166.82273 2019-09-29        134.873157
# 8471       159.91105 2019-11-08        148.066684
# 5937       162.30780 2019-10-03        157.649922

# %% [markdown]
# ### Step 6

# %%
session_df=session_df.set_index('Player.Name')

session_df=session_df.drop([98, 62, 89, 23, 71])

session_df=session_df.set_index('Date', append=True)

session_df.reset_index(level=['Player.Name'], inplace=True)
session_df
# Out:
#             Player.Name Period.Name Position.Name  Total.Player.Load  \
# Date
# 2019-11-08           43     Session             M         1755.08710
# 2019-11-22           43     Session             M         1701.65860
# 2019-09-19           43     Session             M         1672.69440
# 2019-09-13           43     Session             M         1649.17551
# 2019-09-29            4     Session             M         1641.06146
# ...                 ...         ...           ...                ...
# 2019-11-24           34     Session             M            3.73907
# 2019-08-21           34     Session             M            2.00000
# 2019-08-21           12     Session             D            2.00000
# 2019-11-12           66     Session             M            0.99776
# 2019-09-29           49     Session             F            0.32206
#
#             Player.Load.Per.Minute  Maximum.Heart.Rate  Minimum.Heart.Rate  \
# Date
# 2019-11-08                11.85336                 218                   0
# 2019-11-22                12.84722                 229                   0
# 2019-09-19                13.69880                 217                   0
# 2019-09-13                11.38274                 219                   0
# 2019-09-29                10.75199                 205                  94
# ...                            ...                 ...                 ...
# 2019-11-24                 0.09406                   0                   0
# 2019-08-21                 0.11180                 102                   0
# 2019-08-21                 0.11180                 133                 128
# 2019-11-12                 0.10540                   0                   0
# 2019-09-29                 0.13216                   0                   0
#
#             Avg.Heart.Rate  Session.Duration
# Date
# 2019-11-08       162.17158        148.066633
# 2019-11-22       168.91000        132.453449
# 2019-09-19       165.77741        122.105177
# 2019-09-13       164.28843        144.883878
# 2019-09-29       170.58953        152.628626
# ...                    ...               ...
# 2019-11-24         0.00000         39.751967
# 2019-08-21       100.77632         17.889088
# 2019-08-21       130.20000         17.889088
# 2019-11-12         0.00000          9.466414
# 2019-09-29         0.00000          2.436895
#
# [1784 rows x 9 columns]

# %% [markdown]
# ### Step 7

# %%
df_43 = session_df.loc[session_df['Player.Name'] == 43] 
df_43 = df_43.resample('D').sum()
df_43 = df_43.fillna(0)

df_43["Acute_PL"] = (df_43.loc[:,"Total.Player.Load"].rolling('3D', 3).sum())/3
df_43["Chronic_PL"] = (df_43.loc[:,"Total.Player.Load"].rolling('21D', 21).sum())/21
df_43["Acute:Chronic"] = df_43.loc[:,"Acute_PL"]/df_43.loc[:,"Chronic_PL"]

fig, axs = plt.subplots(2,figsize=(20, 10))

axs[0].bar(df_43.index, df_43["Total.Player.Load"])
#axs[0].set_xlabel("Date", fontsize=12)
axs[0].tick_params(axis='x', labelsize=12,)
axs[0].set_ylabel('Average Player Load', fontsize=12)
axs[0].tick_params(axis='y', labelsize=12)
axs[0].set_title("Daily Average Player Load, Player 12 (D)", fontsize=12)

color='#FA8775'
axs[1].set_xlabel("Date", fontsize=12)
axs[1].tick_params(axis='x', labelsize=12, color=color)
axs[1].set_ylabel('Acute PL', color=color, fontsize=12)
axs[1].bar(df_43.index, df_43["Acute_PL"], color=color, alpha=0.6)
axs[1].tick_params(axis='y', labelsize=12)
color='#FFB14E'
axs[1].fill_between(df_43.index, df_43["Chronic_PL"], color=color, alpha=0.8)
axs[1] = plt.gca()
axs[1].set_title("Acute to Chronic Ratio, Player 12 (D)", fontsize=12)
axs1 = axs[1].twinx()  # instantiate a second axes that shares the same x-axis

color='#882C78'
axs1.set_ylabel('Ratio', fontsize=12, color=color)  # we already handled the x-label with ax1
axs1.plot(df_43.index, df_43["Acute:Chronic"], color=color, linewidth=3.0)
axs1.tick_params(axis='y', labelsize=12)
axs1 = plt.gca()

# To see how the acute to chronic workload ratio drops over the first 28 days, 
# comment out this line by adding a '#' in front of the line
axs1.set_ylim([0,3.0])

axs1.axhline(y=1.5,c="gray",linewidth=2,zorder=0)

# %% [markdown]
# ### Step 8

# %%
df_all = session_df.groupby("Date").sum()
df_all = df_all.resample('D').sum()
df_all = df_all.fillna(0)

df_all["Acute_PL"] = (df_all.loc[:,"Total.Player.Load"].rolling('3D', 3).sum())/3
df_all["Chronic_PL"] = (df_all.loc[:,"Total.Player.Load"].rolling('21D', 21).sum())/21
df_all["Acute:Chronic"] = df_all.loc[:,"Acute_PL"]/df_all.loc[:,"Chronic_PL"]

fig, axs = plt.subplots(2,figsize=(20, 10))

axs[0].bar(df_all.index, df_all["Total.Player.Load"])
#axs[0].set_xlabel("Date", fontsize=12)
axs[0].tick_params(axis='x', labelsize=12)
axs[0].set_ylabel('Total Player Load', fontsize=12)
axs[0].tick_params(axis='y', labelsize=12)
axs[0].set_title("Total Player Load, Team", fontsize=12)

color='#FA8775'
axs[1].set_xlabel("Date", fontsize=12)
axs[1].tick_params(axis='x', labelsize=12, color=color)
axs[1].set_ylabel('Acute PL', color=color, fontsize=12)
axs[1].bar(df_all.index, df_all["Acute_PL"], color=color, alpha=0.6)
axs[1].tick_params(axis='y', labelsize=12)

color='#FFB14E'
axs[1].fill_between(df_all.index, df_all["Chronic_PL"], color=color, alpha=0.8)
axs[1] = plt.gca()
axs[1].set_title("Acute to Chronic Ratio, Team", fontsize=12)
axs1 = axs[1].twinx()  # instantiate a second axes that shares the same x-axis

color='#882C78'
axs1.set_ylabel('Ratio', fontsize=12, color=color)  # we already handled the x-label with ax1
axs1.plot(df_all.index, df_all["Acute:Chronic"], color=color, linewidth=3.0)
axs1.tick_params(axis='y', labelsize=12)
axs1 = plt.gca()

# To see how the acute to chronic workload ratio drops over the first 28 days, 
# comment out this line by adding a '#' in front of the line
axs1.set_ylim([0,2.0])

axs1.axhline(y=1.5,c="gray",linewidth=2,zorder=0)

# %% [markdown]
# ### Step 9

# %%
df_all['Above_Thresh'] = np.where(df_all["Acute:Chronic"] > 1.5, 1, 0)

df_all.sort_values(by = 'Above_Thresh', ascending=False)
df_above = df_all[df_all.Above_Thresh == 1]
df_above
# Out:
#             Player.Name  Total.Player.Load  Player.Load.Per.Minute  \
# Date
# 2019-09-29         1031        16510.51763               160.57588
# 2019-11-10          840        13527.89556               143.96280
# 2019-11-24          806        14027.23956               141.80282
#
#             Maximum.Heart.Rate  Minimum.Heart.Rate  Avg.Heart.Rate  \
# Date
# 2019-09-29                3930                 503      2935.97880
# 2019-11-10                2777                 373      2265.97600
# 2019-11-24                1751                   0      1432.14411
#
#             Session.Duration      Acute_PL   Chronic_PL  Acute:Chronic  \
# Date
# 2019-09-29       1955.542138  11844.918730  7760.283862       1.526351
# 2019-11-10       1552.761600  10746.631557  6181.182352       1.738605
# 2019-11-24       1558.522129  10856.481493  5902.242050       1.839383
#
#             Above_Thresh
# Date
# 2019-09-29             1
# 2019-11-10             1
# 2019-11-24             1

# %% [markdown]
# ### Step 10

# %%
Rank_Total_PL = session_df.groupby(['Date'])[['Session.Duration']].sum()
print("Total Player Load captured during entire season")


print(Rank_Total_PL.sort_values(by='Session.Duration', ascending = True))
# Out:
# Total Player Load captured during entire season
#             Session.Duration
# Date
# 2019-08-21        379.616189
# 2019-08-31        401.229387
# 2019-11-09        512.630654
# 2019-10-12        570.699974
# 2019-10-04        668.066767
# ...                      ...
# 2019-08-06       2718.800956
# 2019-09-11       2771.026957
# 2019-08-09       3173.360914
# 2019-08-13       3311.968716
# 2019-08-07       3960.461380
#
# [85 rows x 1 columns]
