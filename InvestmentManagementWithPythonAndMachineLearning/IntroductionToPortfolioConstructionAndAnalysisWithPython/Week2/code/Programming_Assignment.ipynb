# %%
import finance_risk_kit as erk
import pandas as pd
import numpy as np

# %%
# Question 1
hfi = erk.get_hfi_returns("D:\\GitHub\\Coursera\\InvestmentManagementWithPythonAndMachineLearning\\IntroductionToPortfolioConstructionAndAnalysisWithPython\\data\\edhec-hedgefundindices.csv")
hfi_0 = hfi["2000":]

erk.var_gaussian(hfi_0, level=1, modified=False)*100
# Out:
# c:\Python38\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '31/01/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Python38\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '28/02/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Python38\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '31/03/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Python38\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '30/04/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# ...

# %%
# Question 2
erk.var_gaussian(hfi_0, level=1, modified=True)*100
# Out:
# Convertible Arbitrage     10.366556
# CTA Global                 4.664321
# Distressed Securities      4.966909
# Emerging Markets           8.679551
# Equity Market Neutral      4.143206
# Event Driven               4.573181
# Fixed Income Arbitrage     6.647930
# Global Macro               2.278564
# Long/Short Equity          5.138116
# Merger Arbitrage           2.128243
# Relative Value             4.898484
# Short Selling              9.832259
# Funds Of Funds             4.879303
# dtype: float64

# %%
# Question 3
erk.var_historic(hfi_0, level=1)*100
# Out:
# Convertible Arbitrage      3.1674
# CTA Global                 5.0938
# Distressed Securities      4.2642
# Emerging Markets           6.5496
# Equity Market Neutral      1.9800
# Event Driven               3.8540
# Fixed Income Arbitrage     3.0748
# Global Macro               2.2632
# Long/Short Equity          4.5060
# Merger Arbitrage           2.2654
# Relative Value             2.1788
# Short Selling             10.7684
# Funds Of Funds             2.7200
# dtype: float64

# %%
# Question 4
ind = erk.get_ind_returns("D:\\GitHub\\Coursera\\InvestmentManagementWithPythonAndMachineLearning\\IntroductionToPortfolioConstructionAndAnalysisWithPython\\data")
er = erk.annualize_rets(ind["2013":"2017"], 12)
cov = ind["2013":"2017"].cov()
l = ["Books", "Steel", "Oil", "Mines"]
riskfree_rate=0.1

ew = 1/len(l) * 100
ew
# Out:
# 25.0

# %%
# Question 5-7
msr = erk.msr(riskfree_rate, np.array(er[l]), cov.loc[l,l])*100
msr
# Out:
# array([0.00000000e+00, 1.00000000e+02, 2.48065457e-14, 6.44449771e-14])

# %%
# Question 8-10
gmv = erk.gmv(cov.loc[l,l])*100
gmv
# Out:
# array([4.77024876e+01, 6.50521303e-17, 4.34112019e+01, 8.88631054e+00])

# %%
# Question 11
av = erk.portfolio_vol(msr, ind["2018"][l].cov())
av *(12**0.5)
# Out:
# C:\Users\mgy0003\AppData\Local\Temp\ipykernel_18968\2857226963.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   av = erk.portfolio_vol(msr, ind["2018"][l].cov())
# 21.983988181484186

# %%
# Question 12
av2 = erk.portfolio_vol(gmv, ind["2018"][l].cov())
av2 *(12**0.5)
# Out:
# C:\Users\mgy0003\AppData\Local\Temp\ipykernel_18968\1273164371.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   av2 = erk.portfolio_vol(gmv, ind["2018"][l].cov())
# 18.97373447158998
