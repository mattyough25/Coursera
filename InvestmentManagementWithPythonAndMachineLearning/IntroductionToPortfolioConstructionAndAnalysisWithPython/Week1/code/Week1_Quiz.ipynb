# %%
import finance_risk_kit as erk
import pandas as pd
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
# Question 1,3
ffme = erk.get_ffme_returns("D:\\GitHub\\Coursera\\InvestmentManagementWithPythonAndMachineLearning\\IntroductionToPortfolioConstructionAndAnalysisWithPython\\data\\Portfolios_Formed_on_ME_monthly_EW.csv",
                                ['Lo 20', 'Hi 20'])


n_months = ffme.shape[0]
annualized_return = erk.annualize_rets(ffme, 12)
annualized_return
# Out:
# SmallCap    0.151977
# LargeCap    0.098490
# dtype: float64

# %%
# Question 2,4
annualized_vol = erk.annualize_vol(ffme, 12)
annualized_vol
# Out:
# SmallCap    0.336701
# LargeCap    0.195116
# dtype: float64

# %%
# Question 5,7
ffme_99_15 = ffme["1999":"2015"]

n_months = ffme_99_15.shape[0]
annualized_return = erk.annualize_rets(ffme_99_15, 12)
annualized_return
# Out:
# SmallCap    0.114426
# LargeCap    0.062865
# dtype: float64

# %%
# Question 6,8
annualized_vol = erk.annualize_vol(ffme_99_15, 12)
annualized_vol
# Out:
# SmallCap    0.228894
# LargeCap    0.172713
# dtype: float64

# %%
# Question 9
erk.drawdown(ffme_99_15["SmallCap"]).min()
# Out:
# Wealth           1034.189842
# Previous Peak    1111.400000
# Drawdown           -0.624809
# dtype: float64

# %%
# Question 10
erk.drawdown(ffme_99_15["SmallCap"])["Drawdown"].idxmin()
# Out:
# Period('2009-02', 'M')

# %%
# Question 11
erk.drawdown(ffme_99_15["LargeCap"]).min()
# Out:
# Wealth            721.706638
# Previous Peak    1015.300000
# Drawdown           -0.552735
# dtype: float64

# %%
# Question 12
erk.drawdown(ffme_99_15["LargeCap"])["Drawdown"].idxmin()
# Out:
# Period('2009-02', 'M')

# %%
# Question 13, 14
hfi = erk.get_hfi_returns("D:\\GitHub\\Coursera\\InvestmentManagementWithPythonAndMachineLearning\\IntroductionToPortfolioConstructionAndAnalysisWithPython\\data\\edhec-hedgefundindices.csv")
hfi_9 = hfi["2009":]

erk.semideviation(hfi_9).sort_values(ascending=False)
# Out:
# c:\Python38\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '31/01/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Python38\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '28/02/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Python38\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '31/03/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# c:\Python38\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '30/04/1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# ...

# %%
# Question 15
erk.skewness(hfi_9)
# Out:
# Convertible Arbitrage     1.305911
# CTA Global                0.052062
# Distressed Securities    -0.254944
# Emerging Markets          0.033123
# Equity Market Neutral    -0.896327
# Event Driven             -0.488821
# Fixed Income Arbitrage    1.121453
# Global Macro              0.348184
# Long/Short Equity        -0.463703
# Merger Arbitrage         -0.551065
# Relative Value            0.159953
# Short Selling             0.456518
# Funds Of Funds           -0.646908
# dtype: float64

# %%
# Question 16
hfi_0 = hfi['2000':]
erk.kurtosis(hfi_0)
# Out:
# Convertible Arbitrage     23.001449
# CTA Global                 2.845022
# Distressed Securities      6.231720
# Emerging Markets           5.941289
# Equity Market Neutral     20.329621
# Event Driven               5.543444
# Fixed Income Arbitrage    33.378729
# Global Macro               3.653278
# Long/Short Equity          4.472589
# Merger Arbitrage           4.520785
# Relative Value            12.731096
# Short Selling              4.352758
# Funds Of Funds             7.584725
# dtype: float64
